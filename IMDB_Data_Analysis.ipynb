# %% [markdown]
# <a href="https://colab.research.google.com/github/Varshithdevasani/CVIP-Data-Science/blob/main/IMDB_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('imdb_top_1000.csv')

# %%
df.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
df.tail()
# Out:
#                                            Poster_Link  \
# 995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 995  Breakfast at Tiffany's          1961           A  115 min
# 996                   Giant          1956           G  201 min
# 997   From Here to Eternity          1953      Passed  118 min
# 998                Lifeboat          1944         NaN   97 min
# 999            The 39 Steps          1935         NaN   86 min
#
#                         Genre  IMDB_Rating  \
# 995    Comedy, Drama, Romance          7.6
# 996            Drama, Western          7.6
# 997       Drama, Romance, War          7.6
# 998                Drama, War          7.6
# ...

# %%
df.shape
# Out:
# (1000, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Poster_Link    1000 non-null   object
#  1   Series_Title   1000 non-null   object
#  2   Released_Year  1000 non-null   object
#  3   Certificate    899 non-null    object
#  4   Runtime        1000 non-null   object
#  5   Genre          1000 non-null   object
#  6   IMDB_Rating    1000 non-null   float64
#  7   Overview       1000 non-null   object
#  8   Meta_score     843 non-null    float64
#  9   Director       1000 non-null   object
#  10  Star1          1000 non-null   object
#  11  Star2          1000 non-null   object
#  12  Star3          1000 non-null   object
#  13  Star4          1000 non-null   object
#  14  No_of_Votes    1000 non-null   int64
#  15  Gross          831 non-null    object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 125.1+ KB

# %%
df.describe(include='all')
# Out:
#                                               Poster_Link Series_Title  \
# count                                                1000         1000
# unique                                               1000          999
# top     https://m.media-amazon.com/images/M/MV5BMDFkYT...     Drishyam
# freq                                                    1            2
# mean                                                  NaN          NaN
# std                                                   NaN          NaN
# min                                                   NaN          NaN
# 25%                                                   NaN          NaN
# 50%                                                   NaN          NaN
# 75%                                                   NaN          NaN
# max                                                   NaN          NaN
#
#        Released_Year Certificate  Runtime  Genre  IMDB_Rating  \
# ...

# %%
df.isna()
# Out:
#      Poster_Link  Series_Title  Released_Year  Certificate  Runtime  Genre  \
# 0          False         False          False        False    False  False
# 1          False         False          False        False    False  False
# 2          False         False          False        False    False  False
# 3          False         False          False        False    False  False
# 4          False         False          False        False    False  False
# ..           ...           ...            ...          ...      ...    ...
# 995        False         False          False        False    False  False
# 996        False         False          False        False    False  False
# 997        False         False          False        False    False  False
# 998        False         False          False         True    False  False
# 999        False         False          False         True    False  False
#
# ...

# %%
df.isna().sum()
# Out:
# Poster_Link        0
# Series_Title       0
# Released_Year      0
# Certificate      101
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Overview           0
# Meta_score       157
# Director           0
# Star1              0
# Star2              0
# Star3              0
# Star4              0
# No_of_Votes        0
# Gross            169
# dtype: int64

# %%
df=df.dropna(axis=0)

# %%
df=df.dropna(axis=1)

# %%
df.isna().sum()
# Out:
# Poster_Link      0
# Series_Title     0
# Released_Year    0
# Certificate      0
# Runtime          0
# Genre            0
# IMDB_Rating      0
# Overview         0
# Meta_score       0
# Director         0
# Star1            0
# Star2            0
# Star3            0
# Star4            0
# No_of_Votes      0
# Gross            0
# dtype: int64

# %%
dup_df=df.duplicated().any()
print("contains duplicate values",dup_df)
# Out:
# contains duplicate values False

# %%
df
# Out:
#                                            Poster_Link  \
# 0    https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1    https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2    https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3    https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4    https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..                                                 ...
# 990  https://m.media-amazon.com/images/M/MV5BYjRmY2...
# 991  https://m.media-amazon.com/images/M/MV5BMzAyND...
# 992  https://m.media-amazon.com/images/M/MV5BMjAwMT...
# 994  https://m.media-amazon.com/images/M/MV5BZjQyMG...
# 997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# 2             The Dark Knight          2008          UA  152 min
# ...

# %%
df.columns
# Out:
# Index(['Poster_Link', 'Series_Title', 'Released_Year', 'Certificate',
#        'Runtime', 'Genre', 'IMDB_Rating', 'Overview', 'Meta_score', 'Director',
#        'Star1', 'Star2', 'Star3', 'Star4', 'No_of_Votes', 'Gross'],
#       dtype='object')

# %%
df['Released_Year'].value_counts()
# Out:
# 2014    28
# 2004    27
# 2001    24
# 2009    23
# 2013    22
#         ..
# 1941     1
# 1931     1
# 1936     1
# 1942     1
# 1953     1
# Name: Released_Year, Length: 83, dtype: int64

# %%
df.groupby('Released_Year')['IMDB_Rating'].mean()
# Out:
# Released_Year
# 1930    8.000000
# 1931    8.500000
# 1933    7.900000
# 1934    8.100000
# 1936    8.500000
#           ...
# 2016    7.905000
# 2017    7.827778
# 2018    7.950000
# 2019    8.026667
# PG      7.600000
# Name: IMDB_Rating, Length: 83, dtype: float64

# %%
df[df['IMDB_Rating']>=9]['Series_Title']
# Out:
# 0    The Shawshank Redemption
# 1               The Godfather
# 2             The Dark Knight
# 3      The Godfather: Part II
# 4                12 Angry Men
# Name: Series_Title, dtype: object

# %%
df.groupby('Director')['IMDB_Rating'].mean().sort_values(ascending=False)
# Out:
# Director
# Frank Darabont      8.95
# Lana Wachowski      8.70
# Irvin Kershner      8.70
# George Lucas        8.60
# Roberto Benigni     8.60
#                     ...
# Matt Reeves         7.60
# John Lee Hancock    7.60
# Tony Bancroft       7.60
# Alex Proyas         7.60
# Ronny Yu            7.60
# Name: IMDB_Rating, Length: 402, dtype: float64

# %%
df[df['Gross'].max()==df['Gross']]
# Out:
#                                            Poster_Link Series_Title  \
# 529  https://m.media-amazon.com/images/M/MV5BMzIwM2...       Brazil
#
#     Released_Year Certificate  Runtime          Genre  IMDB_Rating  \
# 529          1985           U  132 min  Drama, Sci-Fi          7.9
#
#                                               Overview  Meta_score  \
# 529  A bureaucrat in a dystopic society becomes an ...        84.0
#
#           Director           Star1       Star2           Star3  \
# 529  Terry Gilliam  Jonathan Pryce  Kim Greist  Robert De Niro
#
#                  Star4  No_of_Votes      Gross
# 529  Katherine Helmond       187567  99,29,135

# %%
df.nlargest(10,'Meta_score')['Series_Title']
# Out:
# 1              The Godfather
# 50                Casablanca
# 81               Rear Window
# 116       Lawrence of Arabia
# 119                  Vertigo
# 124             Citizen Kane
# 260    Trois couleurs: Rouge
# 274      Fanny och Alexander
# 423           Il conformista
# 491                  Boyhood
# Name: Series_Title, dtype: object

# %%
df['Meta_score'].max()
# Out:
# 100.0

# %%
top_len=df.nlargest(10,'IMDB_Rating')[['Series_Title','IMDB_Rating']]

# %%
top_len
# Out:
#                                     Series_Title  IMDB_Rating
# 0                       The Shawshank Redemption          9.3
# 1                                  The Godfather          9.2
# 2                                The Dark Knight          9.0
# 3                         The Godfather: Part II          9.0
# 4                                   12 Angry Men          9.0
# 5  The Lord of the Rings: The Return of the King          8.9
# 6                                   Pulp Fiction          8.9
# 7                               Schindler's List          8.9
# 8                                      Inception          8.8
# 9                                     Fight Club          8.8

# %%
def rating(rating):
  if rating>=9:
    return "Excellent"
  elif rating>=8:
      return "Good"
  else:
      return "Average"

# %%
df['Rating']=df['IMDB_Rating'].apply(rating)

# %%
df.head()
# Out:
#                                          Poster_Link  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# 4          Crime, Drama          9.0
#
# ...

# %%
df['Rating'].value_counts()
# Out:
# Average      412
# Good         297
# Excellent      5
# Name: Rating, dtype: int64

# %%
df[df['Runtime'].str.contains('120')]['Series_Title']
# Out:
# 223       Mad Max: Fury Road
# 268                  Platoon
# 279                    Rocky
# 354      Slumdog Millionaire
# 403       Do the Right Thing
# 507               Ying xiong
# 645          Wo hu cang long
# 748       The Social Network
# 753                     Argo
# 765         Efter brylluppet
# 792           Das Experiment
# 834              Blue Velvet
# 858    A Man for All Seasons
# 911       La piel que habito
# 970          My Cousin Vinny
# Name: Series_Title, dtype: object

# %%
df['Genre']
# Out:
# 0                             Drama
# 1                      Crime, Drama
# 2              Action, Crime, Drama
# 3                      Crime, Drama
# 4                      Crime, Drama
#                    ...
# 990             Drama, War, Western
# 991          Adventure, Comedy, War
# 992    Animation, Adventure, Family
# 994          Comedy, Music, Musical
# 997             Drama, Romance, War
# Name: Genre, Length: 714, dtype: object

# %%
df[df['Genre'].str.contains('Comedy')]['Series_Title']
# Out:
# 19                     Gisaengchung
# 26                  La vita è bella
# 35                 The Intouchables
# 47               Back to the Future
# 51                     Modern Times
#                    ...
# 978    Planes, Trains & Automobiles
# 984                The Muppet Movie
# 989                The Long Goodbye
# 991                  Kelly's Heroes
# 994              A Hard Day's Night
# Name: Series_Title, Length: 161, dtype: object

# %%
df['Certificate']
# Out:
# 0           A
# 1           A
# 2          UA
# 3           A
# 4           U
#         ...
# 990        PG
# 991        GP
# 992         U
# 994         U
# 997    Passed
# Name: Certificate, Length: 714, dtype: object

# %%
list1=[]
for value in df['Certificate']:
  list1.append(value.split(','))

# %%
list1
# Out:
# [['A'],
#  ['A'],
#  ['UA'],
#  ['A'],
#  ['U'],
#  ['U'],
#  ['A'],
#  ['A'],
#  ['UA'],
#  ['A'],
#  ['U'],
#  ['UA'],
#  ['A'],
#  ['UA'],
#  ['A'],
#  ['A'],
#  ['UA'],
#  ['A'],
#  ['A'],
#  ['UA'],
#  ['A'],
#  ['U'],
#  ['R'],
#  ['A'],
#  ['U'],
#  ['A'],
#  ['A'],
#  ['UA'],
#  ['U'],
#  ['A'],
#  ['A'],
#  ['UA'],
#  ['U'],
#  ['A'],
#  ['R'],
#  ['UA'],
#  ['R'],
#  ['A'],
#  ['A'],
#  ['U'],
#  ['U'],
#  ['U'],
#  ['U'],
#  ['U'],
#  ['A'],
#  ['U'],
#  ['G'],
#  ['G'],
#  ['A'],
#  ['U'],
#  ['U'],
#  ['UA'],
#  ['UA'],
#  ['U'],
#  ['A'],
#  ['UA'],
#  ['UA'],
#  ['U'],
#  ['A'],
#  ['A'],
#  ['UA'],
#  ['U'],
#  ['A'],
#  ['A'],
#  ['R'],
#  ['R'],
#  ['A'],
#  ['U'],
#  ['R'],
#  ['R'],
#  ['PG-13'],
#  ['R'],
#  ['A'],
#  ['UA'],
#  ['U'],
#  ['UA'],
#  ['A'],
#  ['UA'],
#  ['U'],
#  ['PG'],
#  ['U'],
#  ['A'],
#  ['R'],
#  ['UA'],
#  ['U'],
#  ['R'],
#  ['A'],
#  ['U'],
#  ['R'],
#  ['A'],
#  ['U'],
#  ['A'],
#  ['U'],
#  ['U'],
#  ['U'],
#  ['U'],
#  ['U'],
# ...

# %%
one_d=[]
for item in list1:
  for item1 in item:
    one_d.append(item1)

# %%
one_d
# Out:
# ['A',
#  'A',
#  'UA',
#  'A',
#  'U',
#  'U',
#  'A',
#  'A',
#  'UA',
#  'A',
#  'U',
#  'UA',
#  'A',
#  'UA',
#  'A',
#  'A',
#  'UA',
#  'A',
#  'A',
#  'UA',
#  'A',
#  'U',
#  'R',
#  'A',
#  'U',
#  'A',
#  'A',
#  'UA',
#  'U',
#  'A',
#  'A',
#  'UA',
#  'U',
#  'A',
#  'R',
#  'UA',
#  'R',
#  'A',
#  'A',
#  'U',
#  'U',
#  'U',
#  'U',
#  'U',
#  'A',
#  'U',
#  'G',
#  'G',
#  'A',
#  'U',
#  'U',
#  'UA',
#  'UA',
#  'U',
#  'A',
#  'UA',
#  'UA',
#  'U',
#  'A',
#  'A',
#  'UA',
#  'U',
#  'A',
#  'A',
#  'R',
#  'R',
#  'A',
#  'U',
#  'R',
#  'R',
#  'PG-13',
#  'R',
#  'A',
#  'UA',
#  'U',
#  'UA',
#  'A',
#  'UA',
#  'U',
#  'PG',
#  'U',
#  'A',
#  'R',
#  'UA',
#  'U',
#  'R',
#  'A',
#  'U',
#  'R',
#  'A',
#  'U',
#  'A',
#  'U',
#  'U',
#  'U',
#  'U',
#  'U',
#  'A',
#  'G',
#  'Passed',
#  'UA',
#  'UA',
#  'A',
#  'R',
#  'UA',
#  'A',
#  'U',
#  'A',
#  'U',
#  'A',
#  'UA',
#  'U',
#  'A',
#  'UA',
#  'R',
#  'U',
#  'UA',
#  'A',
#  'A',
#  'A',
# ...

# %%
from collections import Counter as count

# %%
count(one_d)
# Out:
# Counter({'A': 174,
#          'UA': 142,
#          'U': 183,
#          'R': 131,
#          'G': 9,
#          'PG-13': 38,
#          'PG': 19,
#          'Passed': 9,
#          'Approved': 6,
#          'TV-PG': 1,
#          'U/A': 1,
#          'GP': 1})
